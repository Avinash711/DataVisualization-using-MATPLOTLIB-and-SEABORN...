# %%
import seaborn as sns
# %matplotlib inline
tips = sns.load_dataset('tips')
tips.head()
sns.distplot(tips['total_bill'],kde=True,bins=10)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg' )

# %%
import seaborn as sns
tips =sns.load_dataset('tips')
sns.pairplot(tips,hue='sex')

# %%
sns.rugplot(tips['total_bill'])

# %%
#google for kde plot

# %%
import numpy as np
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)

# %%
sns.countplot(x='total_bill',data=tips)

# %%
sns.boxplot(x='sex',y='total_bill',data=tips,hue='day')

# %%
sns.violinplot(x='total_bill',y='day',data=tips,hue='sex',split=True)

# %%
sns.stripplot(x='total_bill',y='day',data=tips,jitter=True)

# %%
sns.violinplot(x='day',y='total_bill',data=tips)
sns.swarmplot(x='day',y='total_bill',data=tips,color='black')

# %%
sns.catplot(x='day',y='total_bill',data=tips,kind='violin')

# %%
fli = sns.load_dataset('flights')

# %%
fli.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
tc = fli.corr()

# %%
sns.heatmap(tc,annot=True,cmap='coolwarm')

# %%
fli=sns.load_dataset('flights')
fp = fli.pivot_table(index='month',columns='year',values='passengers')

# %%
sns.heatmap(fp,cmap='magma',lw=1,linecolor='yellow')

# %%
sns.clustermap(fp)

# %%
iris = sns.load_dataset('iris')
import matplotlib.pyplot as plt
g = sns.PairGrid(iris)
g.map_diag(sns.distplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %%
g=sns.FacetGrid(data=tips,col='time',row='smoker')
g.map(sns.distplot,'total_bill')
